# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

import time
import datetime

from pandas import DataFrame

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy


from datetime import datetime

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(len(cities))
type(cities)
# Out:
# 613
# list

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"


query_url = f"{url}appid={api_key}&units={units}&q="

cit = []
clo = []
cou = []
hum = []
temp = []
temp_max = []
win = []
date = []
lat = []
lon = []
num = 0
set_num = 1

print("Beginning Data Retrieval  ")
print(" - "*25)

for city in cities:
    try:
        print(f"processing record: {num} of set{set_num} | {city}") 
        
        response = requests.get(query_url + city).json()
        
        hum.append(response['main']['humidity'])
        temp.append(response['main']['temp'])
        clo.append(response['clouds']['all'])
        cou.append(response['sys']['country'])
        cit.append(response['name'])
        date.append(response['dt'])
        lat.append(response['coord']['lat'])
        lon.append(response['coord']['lon'])
        temp_max.append(response['main']['temp_max'])
        win.append(response['wind']['speed'])
        
        
                
    except KeyError:
        print("City not found. Skipping...")

    num += 1
 
    if num == 51:
        set_num += 1
        num = 0


print( " - " *25)    
print("Data Retrieval Complete   ")
print( " - " *25)
# Out:
# Beginning Data Retrieval
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# processing record: 0 of set1 | rikitea
# processing record: 1 of set1 | vanimo
# processing record: 2 of set1 | barrow
# processing record: 3 of set1 | ushuaia
# processing record: 4 of set1 | carnarvon
# processing record: 5 of set1 | punta arenas
# processing record: 6 of set1 | lodja
# processing record: 7 of set1 | flinders
# processing record: 8 of set1 | khatanga
# processing record: 9 of set1 | kununurra
# processing record: 10 of set1 | bengkulu
# City not found. Skipping...
# processing record: 11 of set1 | atuona
# processing record: 12 of set1 | kondinskoye
# processing record: 13 of set1 | bonnyville
# processing record: 14 of set1 | yellowknife
# processing record: 15 of set1 | bahia blanca
# processing record: 16 of set1 | nguiu
# City not found. Skipping...
# processing record: 17 of set1 | manakara
# processing record: 18 of set1 | busselton
# processing record: 19 of set1 | houston
# processing record: 20 of set1 | warqla
# City not found. Skipping...
# processing record: 21 of set1 | dwarka
# processing record: 22 of set1 | zeya
# processing record: 23 of set1 | arraial do cabo
# processing record: 24 of set1 | aripuana
# processing record: 25 of set1 | brae
# processing record: 26 of set1 | butaritari
# processing record: 27 of set1 | bethel
# processing record: 28 of set1 | penzance
# processing record: 29 of set1 | camacha
# processing record: 30 of set1 | dukat
# processing record: 31 of set1 | inirida
# processing record: 32 of set1 | ekibastuz
# processing record: 33 of set1 | lekoni
# processing record: 34 of set1 | lagoa
# processing record: 35 of set1 | mataura
# processing record: 36 of set1 | albany
# processing record: 37 of set1 | barentsburg
# City not found. Skipping...
# processing record: 38 of set1 | narsaq
# processing record: 39 of set1 | kapaa
# processing record: 40 of set1 | hobart
# processing record: 41 of set1 | bambous virieux
# processing record: 42 of set1 | ust-kuyga
# processing record: 43 of set1 | bosaso
# processing record: 44 of set1 | avarua
# processing record: 45 of set1 | tombouctou
# processing record: 46 of set1 | castro
# processing record: 47 of set1 | ijaki
# City not found. Skipping...
# processing record: 48 of set1 | quang ngai
# processing record: 49 of set1 | tongren
# processing record: 50 of set1 | leningradskiy
# processing record: 0 of set2 | rockland
# processing record: 1 of set2 | leh
# processing record: 2 of set2 | hermanus
# processing record: 3 of set2 | progreso
# processing record: 4 of set2 | nemuro
# processing record: 5 of set2 | san quintin
# processing record: 6 of set2 | puerto ayora
# processing record: 7 of set2 | cape town
# processing record: 8 of set2 | palabuhanratu
# City not found. Skipping...
# processing record: 9 of set2 | vaini
# processing record: 10 of set2 | sovetsk
# processing record: 11 of set2 | beloha
# processing record: 12 of set2 | saint anthony
# processing record: 13 of set2 | grand river south east
# City not found. Skipping...
# processing record: 14 of set2 | hambantota
# processing record: 15 of set2 | taga
# processing record: 16 of set2 | tuktoyaktuk
# processing record: 17 of set2 | krasnoselkup
# City not found. Skipping...
# processing record: 18 of set2 | port alfred
# processing record: 19 of set2 | kondoa
# processing record: 20 of set2 | san pedro
# processing record: 21 of set2 | qaanaaq
# processing record: 22 of set2 | kingman
# processing record: 23 of set2 | bluff
# processing record: 24 of set2 | sao joao da barra
# processing record: 25 of set2 | maningrida
# processing record: 26 of set2 | amderma
# City not found. Skipping...
# processing record: 27 of set2 | beyneu
# processing record: 28 of set2 | othonoi
# City not found. Skipping...
# processing record: 29 of set2 | taolanaro
# City not found. Skipping...
# processing record: 30 of set2 | bubaque
# processing record: 31 of set2 | mar del plata
# processing record: 32 of set2 | rungata
# City not found. Skipping...
# processing record: 33 of set2 | saint-philippe
# processing record: 34 of set2 | kailua
# processing record: 35 of set2 | mount gambier
# processing record: 36 of set2 | havelock
# processing record: 37 of set2 | umm durman
# City not found. Skipping...
# processing record: 38 of set2 | cherskiy
# processing record: 39 of set2 | turukhansk
# processing record: 40 of set2 | ullapool
# processing record: 41 of set2 | norman wells
# processing record: 42 of set2 | kaitangata
# processing record: 43 of set2 | tiksi
# processing record: 44 of set2 | san juan
# processing record: 45 of set2 | kavieng
# processing record: 46 of set2 | codrington
# processing record: 47 of set2 | mehamn
# processing record: 48 of set2 | arco
# processing record: 49 of set2 | belushya guba
# City not found. Skipping...
# processing record: 50 of set2 | rumonge
# processing record: 0 of set3 | lompoc
# processing record: 1 of set3 | zachagansk
# City not found. Skipping...
# processing record: 2 of set3 | omboue
# processing record: 3 of set3 | port-gentil
# processing record: 4 of set3 | pandaria
# processing record: 5 of set3 | cap malheureux
# processing record: 6 of set3 | ribeira grande
# processing record: 7 of set3 | ilulissat
# processing record: 8 of set3 | mys shmidta
# City not found. Skipping...
# processing record: 9 of set3 | ngorongoro
# processing record: 10 of set3 | puerto escondido
# processing record: 11 of set3 | nong han
# processing record: 12 of set3 | pevek
# processing record: 13 of set3 | baykit
# processing record: 14 of set3 | jamestown
# processing record: 15 of set3 | hualmay
# processing record: 16 of set3 | hami
# processing record: 17 of set3 | rocha
# processing record: 18 of set3 | anloga
# processing record: 19 of set3 | chuy
# processing record: 20 of set3 | chokurdakh
# processing record: 21 of set3 | bara
# processing record: 22 of set3 | san martin
# processing record: 23 of set3 | rosarito
# processing record: 24 of set3 | illoqqortoormiut
# City not found. Skipping...
# processing record: 25 of set3 | bredasdorp
# processing record: 26 of set3 | ostersund
# processing record: 27 of set3 | arlit
# processing record: 28 of set3 | gravdal
# processing record: 29 of set3 | cabo san lucas
# processing record: 30 of set3 | tromso
# processing record: 31 of set3 | sistranda
# processing record: 32 of set3 | nikolskoye
# processing record: 33 of set3 | varzea da palma
# processing record: 34 of set3 | georgetown
# processing record: 35 of set3 | tezu
# processing record: 36 of set3 | quatre cocos
# processing record: 37 of set3 | warrnambool
# processing record: 38 of set3 | sao sebastiao
# processing record: 39 of set3 | dikson
# processing record: 40 of set3 | gueugnon
# processing record: 41 of set3 | broome
# processing record: 42 of set3 | hithadhoo
# processing record: 43 of set3 | lebu
# processing record: 44 of set3 | fallon
# processing record: 45 of set3 | balkanabat
# processing record: 46 of set3 | east london
# processing record: 47 of set3 | isangel
# processing record: 48 of set3 | pine bluff
# processing record: 49 of set3 | wukari
# processing record: 50 of set3 | lagos
# processing record: 0 of set4 | macaboboni
# City not found. Skipping...
# processing record: 1 of set4 | west bay
# processing record: 2 of set4 | manzanillo
# processing record: 3 of set4 | bucak
# processing record: 4 of set4 | mentok
# City not found. Skipping...
# processing record: 5 of set4 | kencong
# processing record: 6 of set4 | mahasamund
# processing record: 7 of set4 | hilo
# processing record: 8 of set4 | victoria
# processing record: 9 of set4 | sol-iletsk
# processing record: 10 of set4 | teguise
# processing record: 11 of set4 | flin flon
# processing record: 12 of set4 | abbiategrasso
# processing record: 13 of set4 | olafsvik
# City not found. Skipping...
# processing record: 14 of set4 | souillac
# processing record: 15 of set4 | tandil
# processing record: 16 of set4 | atar
# processing record: 17 of set4 | santa ana
# processing record: 18 of set4 | paamiut
# processing record: 19 of set4 | clyde river
# processing record: 20 of set4 | kirakira
# processing record: 21 of set4 | denizli
# processing record: 22 of set4 | dzhusaly
# City not found. Skipping...
# processing record: 23 of set4 | charters towers
# processing record: 24 of set4 | latung
# processing record: 25 of set4 | pangnirtung
# processing record: 26 of set4 | salamina
# processing record: 27 of set4 | toora-khem
# processing record: 28 of set4 | biltine
# processing record: 29 of set4 | husavik
# processing record: 30 of set4 | ajdabiya
# processing record: 31 of set4 | provideniya
# processing record: 32 of set4 | teruel
# processing record: 33 of set4 | alcudia
# processing record: 34 of set4 | kamina
# processing record: 35 of set4 | maghama
# City not found. Skipping...
# processing record: 36 of set4 | kruisfontein
# processing record: 37 of set4 | vaitupu
# City not found. Skipping...
# processing record: 38 of set4 | katsuura
# processing record: 39 of set4 | airai
# processing record: 40 of set4 | lakes entrance
# processing record: 41 of set4 | padang
# processing record: 42 of set4 | gat
# processing record: 43 of set4 | vauvert
# processing record: 44 of set4 | saleaula
# City not found. Skipping...
# processing record: 45 of set4 | cozumel
# City not found. Skipping...
# processing record: 46 of set4 | asyut
# processing record: 47 of set4 | asmar
# processing record: 48 of set4 | muscat
# processing record: 49 of set4 | port lincoln
# processing record: 50 of set4 | vrangel
# processing record: 0 of set5 | nagram
# processing record: 1 of set5 | constitucion
# processing record: 2 of set5 | kendari
# processing record: 3 of set5 | qafqafa
# processing record: 4 of set5 | katherine
# processing record: 5 of set5 | dampit
# processing record: 6 of set5 | zyryanka
# processing record: 7 of set5 | beyla
# processing record: 8 of set5 | ilhabela
# processing record: 9 of set5 | kiama
# processing record: 10 of set5 | lavrentiya
# processing record: 11 of set5 | itarema
# processing record: 12 of set5 | kadykchan
# City not found. Skipping...
# processing record: 13 of set5 | vostok
# processing record: 14 of set5 | esmeraldas
# processing record: 15 of set5 | christchurch
# processing record: 16 of set5 | fort nelson
# processing record: 17 of set5 | hamilton
# processing record: 18 of set5 | kavaratti
# processing record: 19 of set5 | asmara
# processing record: 20 of set5 | sillod
# processing record: 21 of set5 | novopokrovka
# processing record: 22 of set5 | saint george
# processing record: 23 of set5 | pagman
# City not found. Skipping...
# processing record: 24 of set5 | ha
# City not found. Skipping...
# processing record: 25 of set5 | san ignacio
# processing record: 26 of set5 | taoudenni
# processing record: 27 of set5 | bakchar
# processing record: 28 of set5 | asau
# City not found. Skipping...
# processing record: 29 of set5 | port elizabeth
# processing record: 30 of set5 | ler
# processing record: 31 of set5 | necochea
# processing record: 32 of set5 | thompson
# processing record: 33 of set5 | goderich
# processing record: 34 of set5 | westport
# processing record: 35 of set5 | ambilobe
# processing record: 36 of set5 | san patricio
# processing record: 37 of set5 | antofagasta
# processing record: 38 of set5 | aldan
# processing record: 39 of set5 | shirokiy
# processing record: 40 of set5 | sitka
# processing record: 41 of set5 | coro
# processing record: 42 of set5 | kawalu
# processing record: 43 of set5 | grindavik
# processing record: 44 of set5 | talara
# processing record: 45 of set5 | ayan
# processing record: 46 of set5 | oyon
# processing record: 47 of set5 | tadine
# processing record: 48 of set5 | kabinda
# processing record: 49 of set5 | ammon
# processing record: 50 of set5 | torbay
# processing record: 0 of set6 | manokwari
# processing record: 1 of set6 | cayenne
# processing record: 2 of set6 | okhotsk
# processing record: 3 of set6 | moose factory
# processing record: 4 of set6 | lolua
# City not found. Skipping...
# processing record: 5 of set6 | batagay
# processing record: 6 of set6 | sentyabrskiy
# City not found. Skipping...
# processing record: 7 of set6 | severnyy
# City not found. Skipping...
# processing record: 8 of set6 | yulara
# processing record: 9 of set6 | vastervik
# City not found. Skipping...
# processing record: 10 of set6 | garden city
# processing record: 11 of set6 | annau
# processing record: 12 of set6 | swan river
# processing record: 13 of set6 | seoul
# processing record: 14 of set6 | cidreira
# processing record: 15 of set6 | tasiilaq
# processing record: 16 of set6 | fare
# processing record: 17 of set6 | haines junction
# processing record: 18 of set6 | usman
# processing record: 19 of set6 | kokopo
# processing record: 20 of set6 | nome
# processing record: 21 of set6 | vilhena
# processing record: 22 of set6 | turochak
# processing record: 23 of set6 | asuncion
# processing record: 24 of set6 | los llanos de aridane
# processing record: 25 of set6 | nanortalik
# processing record: 26 of set6 | port keats
# processing record: 27 of set6 | dolbeau
# City not found. Skipping...
# processing record: 28 of set6 | oyama
# processing record: 29 of set6 | arvika
# processing record: 30 of set6 | arkhangelsk
# processing record: 31 of set6 | trincomalee
# processing record: 32 of set6 | urumqi
# City not found. Skipping...
# processing record: 33 of set6 | mackay
# processing record: 34 of set6 | nicoya
# processing record: 35 of set6 | forecariah
# processing record: 36 of set6 | san rafael
# processing record: 37 of set6 | baruun-urt
# processing record: 38 of set6 | kashi
# City not found. Skipping...
# processing record: 39 of set6 | la ronge
# processing record: 40 of set6 | karratha
# processing record: 41 of set6 | samusu
# City not found. Skipping...
# processing record: 42 of set6 | uvat
# processing record: 43 of set6 | talnakh
# processing record: 44 of set6 | pacific grove
# processing record: 45 of set6 | wahran
# City not found. Skipping...
# processing record: 46 of set6 | port hedland
# processing record: 47 of set6 | avera
# processing record: 48 of set6 | suntar
# processing record: 49 of set6 | praia da vitoria
# processing record: 50 of set6 | peniche
# processing record: 0 of set7 | coahuayana
# processing record: 1 of set7 | viligili
# City not found. Skipping...
# processing record: 2 of set7 | srednekolymsk
# processing record: 3 of set7 | gambela
# processing record: 4 of set7 | jarjis
# City not found. Skipping...
# processing record: 5 of set7 | yashkul
# processing record: 6 of set7 | planeta rica
# processing record: 7 of set7 | samana
# processing record: 8 of set7 | wakkanai
# processing record: 9 of set7 | champerico
# processing record: 10 of set7 | the valley
# processing record: 11 of set7 | ajijic
# processing record: 12 of set7 | seguin
# processing record: 13 of set7 | san-pedro
# processing record: 14 of set7 | khromtau
# processing record: 15 of set7 | fukue
# processing record: 16 of set7 | naraina
# processing record: 17 of set7 | mapimi
# processing record: 18 of set7 | saskylakh
# processing record: 19 of set7 | adrar
# processing record: 20 of set7 | sabalgarh
# processing record: 21 of set7 | sarangani
# processing record: 22 of set7 | lufilufi
# processing record: 23 of set7 | walvis bay
# processing record: 24 of set7 | bereda
# processing record: 25 of set7 | tuatapere
# processing record: 26 of set7 | hasaki
# processing record: 27 of set7 | talcahuano
# processing record: 28 of set7 | shingu
# processing record: 29 of set7 | ardakan
# processing record: 30 of set7 | tautira
# processing record: 31 of set7 | alfred
# processing record: 32 of set7 | tchollire
# processing record: 33 of set7 | ukiah
# processing record: 34 of set7 | tallahassee
# processing record: 35 of set7 | maceio
# processing record: 36 of set7 | bangui
# processing record: 37 of set7 | caraquet
# processing record: 38 of set7 | port blair
# processing record: 39 of set7 | aykhal
# processing record: 40 of set7 | igarka
# processing record: 41 of set7 | tigil
# processing record: 42 of set7 | vila franca do campo
# processing record: 43 of set7 | canon city
# processing record: 44 of set7 | old town
# processing record: 45 of set7 | jasper
# processing record: 46 of set7 | salalah
# processing record: 47 of set7 | kodiak
# processing record: 48 of set7 | tsihombe
# City not found. Skipping...
# processing record: 49 of set7 | cheuskiny
# City not found. Skipping...
# processing record: 50 of set7 | koumac
# processing record: 0 of set8 | berlevag
# processing record: 1 of set8 | gizo
# processing record: 2 of set8 | bonthe
# processing record: 3 of set8 | luderitz
# processing record: 4 of set8 | ivankiv
# processing record: 5 of set8 | vardo
# processing record: 6 of set8 | thunder bay
# processing record: 7 of set8 | sangin
# processing record: 8 of set8 | laksham
# processing record: 9 of set8 | humberto de campos
# processing record: 10 of set8 | sabha
# processing record: 11 of set8 | mandurah
# processing record: 12 of set8 | bikaner
# processing record: 13 of set8 | yomitan
# City not found. Skipping...
# processing record: 14 of set8 | domodossola
# processing record: 15 of set8 | tete
# processing record: 16 of set8 | sorland
# processing record: 17 of set8 | harwich
# processing record: 18 of set8 | naze
# processing record: 19 of set8 | kalmunai
# processing record: 20 of set8 | mecca
# processing record: 21 of set8 | cabedelo
# processing record: 22 of set8 | tunduru
# City not found. Skipping...
# processing record: 23 of set8 | fevralsk
# City not found. Skipping...
# processing record: 24 of set8 | male
# processing record: 25 of set8 | snasa
# processing record: 26 of set8 | maralal
# processing record: 27 of set8 | faanui
# processing record: 28 of set8 | iralaya
# processing record: 29 of set8 | buala
# processing record: 30 of set8 | gore
# processing record: 31 of set8 | touros
# processing record: 32 of set8 | togur
# processing record: 33 of set8 | celestun
# processing record: 34 of set8 | molchanovo
# processing record: 35 of set8 | joshimath
# processing record: 36 of set8 | lewistown
# processing record: 37 of set8 | tura
# processing record: 38 of set8 | sambava
# processing record: 39 of set8 | sao filipe
# processing record: 40 of set8 | daru
# processing record: 41 of set8 | udachnyy
# processing record: 42 of set8 | sorvag
# City not found. Skipping...
# processing record: 43 of set8 | gorin
# processing record: 44 of set8 | kuche
# City not found. Skipping...
# processing record: 45 of set8 | jurado
# City not found. Skipping...
# processing record: 46 of set8 | mandera
# processing record: 47 of set8 | bathsheba
# processing record: 48 of set8 | tibati
# processing record: 49 of set8 | palmer
# processing record: 50 of set8 | kulunda
# processing record: 0 of set9 | takoradi
# processing record: 1 of set9 | gorontalo
# processing record: 2 of set9 | labuhan
# processing record: 3 of set9 | ancud
# processing record: 4 of set9 | malwan
# City not found. Skipping...
# processing record: 5 of set9 | ntoum
# processing record: 6 of set9 | new norfolk
# processing record: 7 of set9 | coos bay
# processing record: 8 of set9 | buin
# processing record: 9 of set9 | yar-sale
# processing record: 10 of set9 | canberra
# processing record: 11 of set9 | nelson bay
# processing record: 12 of set9 | roncesvalles
# processing record: 13 of set9 | severo-kurilsk
# processing record: 14 of set9 | marsh harbour
# processing record: 15 of set9 | coihaique
# processing record: 16 of set9 | carutapera
# processing record: 17 of set9 | vilcun
# processing record: 18 of set9 | mahebourg
# processing record: 19 of set9 | keetmanshoop
# processing record: 20 of set9 | kolyvan
# processing record: 21 of set9 | richards bay
# processing record: 22 of set9 | rio gallegos
# processing record: 23 of set9 | camana
# City not found. Skipping...
# processing record: 24 of set9 | la cruz
# processing record: 25 of set9 | burnie
# processing record: 26 of set9 | achacachi
# processing record: 27 of set9 | goleniow
# processing record: 28 of set9 | upernavik
# processing record: 29 of set9 | codajas
# processing record: 30 of set9 | bambanglipuro
# processing record: 31 of set9 | grand gaube
# processing record: 32 of set9 | poum
# processing record: 33 of set9 | erzincan
# processing record: 34 of set9 | mumbwa
# processing record: 35 of set9 | erenhot
# processing record: 36 of set9 | mayskiy
# processing record: 37 of set9 | revda
# processing record: 38 of set9 | plettenberg bay
# processing record: 39 of set9 | deputatskiy
# processing record: 40 of set9 | gollere
# City not found. Skipping...
# processing record: 41 of set9 | coquimbo
# processing record: 42 of set9 | orlik
# processing record: 43 of set9 | kudahuvadhoo
# processing record: 44 of set9 | alta floresta
# processing record: 45 of set9 | nhulunbuy
# processing record: 46 of set9 | usinsk
# processing record: 47 of set9 | samalaeulu
# City not found. Skipping...
# processing record: 48 of set9 | meyungs
# City not found. Skipping...
# processing record: 49 of set9 | rio grande
# processing record: 50 of set9 | serafimovskiy
# processing record: 0 of set10 | varna
# processing record: 1 of set10 | vavatenina
# processing record: 2 of set10 | coffs harbour
# processing record: 3 of set10 | norden
# processing record: 4 of set10 | sangareddi
# processing record: 5 of set10 | novouzensk
# processing record: 6 of set10 | khonsa
# processing record: 7 of set10 | erzin
# processing record: 8 of set10 | dongsheng
# processing record: 9 of set10 | half moon bay
# processing record: 10 of set10 | aksarka
# processing record: 11 of set10 | fortuna
# processing record: 12 of set10 | mkuranga
# processing record: 13 of set10 | mizan teferi
# processing record: 14 of set10 | saldanha
# processing record: 15 of set10 | jaipur hat
# City not found. Skipping...
# processing record: 16 of set10 | banihal
# processing record: 17 of set10 | salinas
# processing record: 18 of set10 | ponta do sol
# processing record: 19 of set10 | goksun
# processing record: 20 of set10 | hilter
# processing record: 21 of set10 | batouri
# processing record: 22 of set10 | morrope
# processing record: 23 of set10 | araouane
# processing record: 24 of set10 | pedernales
# processing record: 25 of set10 | claresholm
# processing record: 26 of set10 | atbasar
# processing record: 27 of set10 | gushikawa
# processing record: 28 of set10 | glendive
# processing record: 29 of set10 | shumerlya
# processing record: 30 of set10 | lokosovo
# processing record: 31 of set10 | geraldton
# processing record: 32 of set10 | nouadhibou
# processing record: 33 of set10 | kulhudhuffushi
# processing record: 34 of set10 | attawapiskat
# City not found. Skipping...
# processing record: 35 of set10 | road town
# processing record: 36 of set10 | basco
# processing record: 37 of set10 | kasongo
# processing record: 38 of set10 | san cristobal
# processing record: 39 of set10 | olinda
# processing record: 40 of set10 | peace river
# processing record: 41 of set10 | alice springs
# processing record: 42 of set10 | anchorage
# processing record: 43 of set10 | verkhnyaya toyma
# processing record: 44 of set10 | nishihara
# processing record: 45 of set10 | amarpur
# processing record: 46 of set10 | ivanava
# processing record: 47 of set10 | bukachacha
# processing record: 48 of set10 | laguna de perlas
# processing record: 49 of set10 | te anau
# processing record: 50 of set10 | ixtapa
# processing record: 0 of set11 | le port
# processing record: 1 of set11 | trento
# processing record: 2 of set11 | ambon
# processing record: 3 of set11 | marcona
# City not found. Skipping...
# processing record: 4 of set11 | yibin
# processing record: 5 of set11 | loa janan
# processing record: 6 of set11 | nan
# processing record: 7 of set11 | pisco
# processing record: 8 of set11 | dekar
# processing record: 9 of set11 | khasan
# processing record: 10 of set11 | ocos
# processing record: 11 of set11 | oranjestad
# processing record: 12 of set11 | dapaong
# processing record: 13 of set11 | dzaoudzi
# processing record: 14 of set11 | teya
# processing record: 15 of set11 | vestmannaeyjar
# processing record: 16 of set11 | lexington
# processing record: 17 of set11 | mahaicony
# City not found. Skipping...
# processing record: 18 of set11 | marystown
# processing record: 19 of set11 | klaksvik
# processing record: 20 of set11 | atocha
# processing record: 21 of set11 | tumannyy
# City not found. Skipping...
# processing record: 22 of set11 | zhuhai
# processing record: 23 of set11 | harper
# processing record: 24 of set11 | ruian
# City not found. Skipping...
# processing record: 25 of set11 | lesnoy
# processing record: 26 of set11 | marv dasht
# City not found. Skipping...
# processing record: 27 of set11 | berdigestyakh
# processing record: 28 of set11 | meulaboh
# processing record: 29 of set11 | yumen
# processing record: 30 of set11 | pombas
# processing record: 31 of set11 | yermakovskoye
# processing record: 32 of set11 | lazaro cardenas
# processing record: 33 of set11 | vao
# processing record: 34 of set11 | pochutla
# processing record: 35 of set11 | jijiga
# processing record: 36 of set11 | swan hill
# processing record: 37 of set11 | batagay-alyta
# processing record: 38 of set11 | sargur
# processing record: 39 of set11 | sulangan
# processing record: 40 of set11 | rundu
# processing record: 41 of set11 | redhakhol
# City not found. Skipping...
# processing record: 42 of set11 | ust-omchug
# processing record: 43 of set11 | dharchula
# processing record: 44 of set11 | rawson
# processing record: 45 of set11 | bagdarin
# processing record: 46 of set11 | itoigawa
# processing record: 47 of set11 | semnan
# processing record: 48 of set11 | nizhniy kuranakh
# processing record: 49 of set11 | mrirt
# City not found. Skipping...
# processing record: 50 of set11 | longyearbyen
# processing record: 0 of set12 | zelenoborskiy
# processing record: 1 of set12 | aklavik
# processing record: 2 of set12 | hofn
# processing record: 3 of set12 | iqaluit
# processing record: 4 of set12 | ahipara
# processing record: 5 of set12 | yershichi
# processing record: 6 of set12 | miri
# processing record: 7 of set12 | thilogne
# City not found. Skipping...
# processing record: 8 of set12 | katobu
# processing record: 9 of set12 | farah
# processing record: 10 of set12 | verkhnevilyuysk
# processing record: 11 of set12 | huancavelica
# processing record: 12 of set12 | moussoro
# processing record: 13 of set12 | nizhneyansk
# City not found. Skipping...
# processing record: 14 of set12 | villa carlos paz
# processing record: 15 of set12 | pavino
# processing record: 16 of set12 | lyman
# processing record: 17 of set12 | lixourion
# processing record: 18 of set12 | dobryanka
# processing record: 19 of set12 | pervomayskoye
# processing record: 20 of set12 | port hueneme
# processing record: 21 of set12 | hobyo
# processing record: 22 of set12 | tshikapa
# processing record: 23 of set12 | mashhad
# processing record: 24 of set12 | karaul
# City not found. Skipping...
# processing record: 25 of set12 | general roca
# processing record: 26 of set12 | saint-francois
# processing record: 27 of set12 | manaure
# processing record: 28 of set12 | ganzhou
# processing record: 29 of set12 | chagda
# City not found. Skipping...
# processing record: 30 of set12 | saint-augustin
# processing record: 31 of set12 | gornopravdinsk
# processing record: 32 of set12 | arroyo
# processing record: 33 of set12 | alofi
# processing record: 34 of set12 | sibolga
# processing record: 35 of set12 | westerland
# processing record: 36 of set12 | alekseyevka
# processing record: 37 of set12 | namibe
# processing record: 38 of set12 | mormugao
# City not found. Skipping...
# processing record: 39 of set12 | saint-pierre
# processing record: 40 of set12 | santa maria
# processing record: 41 of set12 | mitchell
# processing record: 42 of set12 | guerrero negro
# processing record: 43 of set12 | rafai
# processing record: 44 of set12 | qasigiannguit
# processing record: 45 of set12 | shahr-e babak
# processing record: 46 of set12 | chkalovsk
# processing record: 47 of set12 | aden
# processing record: 48 of set12 | sangar
# processing record: 49 of set12 | faya
# processing record: 50 of set12 | malakal
# City not found. Skipping...
# processing record: 0 of set13 | skagastrond
# City not found. Skipping...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Data Retrieval Complete
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_dict = {
    "City": cit,
    "Cloudiness": clo,
    "Country": cou,
    "Date": date,
    "Humidity": hum,
    "Lat": lat,
    "Lng": lon,
    "Max Temp": temp_max,
    "Wind Speed": win
    
}
weather_data = pd.DataFrame(weather_dict)
weather_data
# Out:
#               City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0          Rikitea          37      PF  1573698821        78 -23.12 -134.97
# 1           Vanimo         100      PG  1573698223        74  -2.67  141.30
# 2           Barrow           0      AR  1573698223        94 -38.31  -60.23
# 3          Ushuaia           0      AR  1573698223        66 -54.81  -68.31
# 4        Carnarvon           0      ZA  1573698224        81 -30.97   22.13
# ..             ...         ...     ...         ...       ...    ...     ...
# 539  Shahr-e Babak           0      IR  1573698921        14  30.12   55.12
# 540      Chkalovsk          90      RU  1573698921        90  56.76   43.24
# 541           Aden           0      YE  1573698921        73  12.79   45.03
# 542         Sangar         100      RU  1573698921        96  63.92  127.47
# 543           Faya           3      SA  1573698922        76  18.39   42.45
#
#      Max Temp  Wind Speed
# 0       71.37       22.68
# 1       81.70        1.10
# 2       54.82        5.23
# 3       50.00       11.41
# 4       49.64       12.64
# ..        ...         ...
# 539     34.66        1.50
# 540     32.00        4.47
# 541     75.99        9.57
# 542    -16.97        4.72
# 543     55.40        1.34
#
# [544 rows x 9 columns]

# %%
DataFrame.to_csv(weather_data)
# Out:
# ',City,Cloudiness,Country,Date,Humidity,Lat,Lng,Max Temp,Wind Speed\r\n0,Rikitea,37,PF,1573698821,78,-23.12,-134.97,71.37,22.68\r\n1,Vanimo,100,PG,1573698223,74,-2.67,141.3,81.7,1.1\r\n2,Barrow,0,AR,1573698223,94,-38.31,-60.23,54.82,5.23\r\n3,Ushuaia,0,AR,1573698223,66,-54.81,-68.31,50.0,11.41\r\n4,Carnarvon,0,ZA,1573698224,81,-30.97,22.13,49.64,12.64\r\n5,Punta Arenas,90,CL,1573698224,81,-53.16,-70.91,50.0,8.05\r\n6,Lodja,100,CD,1573698224,99,-3.52,23.6,69.87,1.54\r\n7,Flinders,0,AU,1573698224,22,-34.58,150.85,78.8,10.29\r\n8,Khatanga,100,RU,1573698224,88,71.98,102.47,-19.88,8.19\r\n9,Kununurra,0,AU,1573698224,44,-15.77,128.74,95.0,8.05\r\n10,Atuona,0,PF,1573698224,73,-9.8,-139.03,79.97,14.0\r\n11,Kondinskoye,0,RU,1573698224,94,59.65,67.41,-6.07,6.33\r\n12,Bonnyville,20,CA,1573698225,85,54.27,-110.74,24.8,3.36\r\n13,Yellowknife,20,CA,1573698127,76,62.45,-114.38,-4.01,11.41\r\n14,Bahia Blanca,5,AR,1573697977,86,-38.72,-62.27,59.92,8.32\r\n15,Manakara,57,MG,1573698225,93,-22.14,48.01,74.68,3.53\r\n16,Busselton,0,AU,1573698225,44,-33.64,115.35,79.92,7.47\r\n17,Houston,90,US,1573698317,61,29.76,-95.37,46.4,2.59\r\n18,Dwarka,40,IN,1573698226,77,28.58,77.04,64.4,3.36\r\n19,Zeya,11,RU,1573698226,83,53.74,127.27,-8.56,4.36\r\n20,Arraial do Cabo,76,BR,1573698226,86,-22.97,-42.02,73.4,25.1\r\n21,Aripuana,94,BR,1573698226,89,-9.17,-60.63,74.03,1.7\r\n22,Brae,78,GB,1573698226,61,60.4,-1.35,35.6,5.82\r\n23,Butaritari,100,KI,1573698227,76,3.07,172.79,84.6,12.06\r\n24,Bethel,1,US,1573697964,66,60.79,-161.76,12.2,33.33\r\n25,Penzance,100,GB,1573698227,81,50.12,-5.53,42.8,12.75\r\n26,Camacha,75,PT,1573698227,68,33.08,-16.33,66.2,9.17\r\n27,Dukat,100,AL,1573698227,72,40.25,19.57,64.4,11.23\r\n28,Inirida,97,CO,1573698227,92,3.87,-67.92,74.59,1.72\r\n29,Ekibastuz,100,KZ,1573698227,96,51.72,75.32,24.31,5.08\r\n30,Lekoni,98,GA,1573698227,88,-1.58,14.26,72.52,1.48\r\n31,Lagoa,70,PT,1573698228,87,37.14,-8.45,53.6,4.7\r\n32,Mataura,37,NZ,1573698228,92,-46.19,168.86,53.53,8.5\r\n33,Albany,90,US,1573698022,57,42.65,-73.75,21.2,3.36\r\n34,Narsaq,100,GL,1573698228,74,60.91,-46.05,39.2,29.97\r\n35,Kapaa,75,US,1573698228,74,22.08,-159.32,82.4,6.93\r\n36,Hobart,75,AU,1573698224,32,-42.88,147.33,66.2,35.57\r\n37,Bambous Virieux,75,MU,1573698228,83,-20.34,57.76,75.2,8.05\r\n38,Ust-Kuyga,60,RU,1573698229,99,70.0,135.55,-19.11,3.74\r\n39,Bosaso,15,SO,1573698229,78,11.28,49.18,80.04,16.04\r\n40,Avarua,98,CK,1573698229,88,-21.21,-159.78,75.2,8.05\r\n41,Timbuktu,0,ML,1573698229,25,16.77,-3.01,69.98,10.65\r\n42,Castro,6,CL,1573698229,93,-42.48,-73.76,50.0,4.7\r\n43,Quang Ngai,19,VN,1573698229,73,15.12,108.8,78.42,17.92\r\n44,Tongren,0,CN,1573698229,47,27.72,109.18,59.43,3.09\r\n45,Leningradskiy,100,RU,1573698229,79,69.38,178.42,23.34,25.86\r\n46,Rockland,90,CA,1573697949,78,45.55,-75.29,12.2,3.62\r\n47,Leh,100,IN,1573698230,54,34.16,77.58,20.71,4.18\r\n48,Hermanus,0,ZA,1573698230,85,-34.42,19.24,63.1,20.47\r\n49,Progreso,75,UY,1573698230,93,-34.68,-56.22,66.2,1.66\r\n50,Nemuro,75,JP,1573698230,82,43.32,145.57,57.2,18.34\r\n51,San Quintin,41,PH,1573698230,65,17.54,120.52,82.72,18.01\r\n52,Puerto Ayora,74,EC,1573698189,84,-0.74,-90.35,69.3,13.69\r\n53,Cape Town,33,ZA,1573698001,63,-33.93,18.42,64.4,29.97\r\n54,Vaini,0,IN,1573698231,82,15.34,74.49,64.4,9.75\r\n55,Sovetsk,100,RU,1573698231,81,55.08,21.89,54.14,14.29\r\n56,Beloha,77,MG,1573698231,91,-25.17,45.06,71.62,8.63\r\n57,Saint Anthony,1,US,1573698231,55,43.97,-111.68,41.0,4.07\r\n58,Hambantota,20,LK,1573698231,100,6.12,81.12,75.2,1.12\r\n59,Taga,0,ID,1573698231,32,-8.61,120.44,89.65,5.79\r\n60,Tuktoyaktuk,90,CA,1573698232,76,69.44,-133.03,-4.01,13.87\r\n61,Port Alfred,82,ZA,1573698232,78,-33.59,26.89,61.97,11.56\r\n62,Kondoa,46,TZ,1573698232,89,-4.91,35.78,63.43,7.74\r\n63,San Pedro,0,AR,1573698232,76,-33.68,-59.66,67.21,2.66\r\n64,Qaanaaq,64,GL,1573698232,65,77.48,-69.36,17.89,9.57\r\n65,Kingman,1,US,1573698232,15,35.19,-114.05,69.8,0.78\r\n66,Bluff,27,AU,1573698232,18,-23.58,149.07,90.25,7.92\r\n67,Sao Joao da ...

# %%
# date_time = datetime.fromtimestamp(weather_data["Date"])                          
# weather_data["Date_time"] = date_time

# weather_data.head()

d = datetime.fromtimestamp(weather_data["Date"])
d
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-64-1df127618d37> in <module>
#       4 # weather_data.head()
#       5
# ----> 6 d = datetime.fromtimestamp(weather_data["Date"])
#       7 d
#       8
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in wrapper(self)
#     129         if len(self) == 1:
#     130             return converter(self.iloc[0])
# --> 131         raise TypeError("cannot convert the series to " "{0}".format(str(converter)))
#     132
#     133     wrapper.__name__ = "__{name}__".format(name=converter.__name__)
#
# TypeError: cannot convert the series to <class 'int'>

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(weather_data["Lat"], weather_data["Max Temp"], marker="o")

# Incorporate the other graph properties
plt.title("Latitude vs. Temperature Plot")
plt.ylabel("Max Temp (F)")
plt.xlabel("Latitude")
plt.grid(True)

# add labels to points in plot
# for index,row in weather_data.iterrows():
#     plt.annotate(row['City'], (row['Lat'], row['Max Temp']))

# Save the figure
plt.savefig("TemperatureInWorldCities.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(weather_data["Lat"], weather_data["Humidity"], marker="o")

# Incorporate the other graph properties
plt.title("Latitude vs. Humidity Plot")
plt.ylabel("Temperature (F)")
plt.xlabel("Humidity")
plt.grid(True)



# Save the figure
plt.savefig("Latitude vs. Humidity Plot.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_data["Lat"], weather_data["Cloudiness"], marker="o")

# Incorporate the other graph properties
plt.title("Latitude vs. Cloudiness Plot")
plt.ylabel("Cloudiness")
plt.xlabel("Latitude")
plt.grid(True)



# Save the figure
plt.savefig("Latitude vs. Cloudiness Plot.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_data["Lat"], weather_data["Wind Speed"], marker="o")

# Incorporate the other graph properties
plt.title("Latitude vs. Wind Speed Plot")
plt.ylabel(" Wind Speed")
plt.xlabel("Latitude")
plt.grid(True)



# Save the figure
plt.savefig("Latitude vs. Wind Speed Plot.png")

# Show plot
plt.show()
